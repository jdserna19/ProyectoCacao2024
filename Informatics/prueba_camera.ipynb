# %% [markdown]
# # Foto usando Matplotlib y OpenCV
#
# Este programa permite capturar una imagen de una camara USB y graficarla usando la librería Matplotlib

# %% [markdown]
# ## Librerias

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## Constantes

# %%
NUM_CAMERA = 0 # Camara numero 0

# %% [markdown]
# ## Capturar Imagen

# %%
camera = cv2.VideoCapture(NUM_CAMERA)
return_value, image = camera.read()

# Liberar camara
del camera

# %% [markdown]
# ## Mostrar imagen usando Matplotlib

# %%
plt.imshow(image)
plt.title("Captured Image")
plt.axis("off")  # Hide axes
plt.show()

# %% [markdown]
# ## Guardar imagen en disco

# %%
cv2.imwrite('./pictures/imagen1.png', image)
# Out:
# True
